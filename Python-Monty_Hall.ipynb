# %%
# Plantear el dilema de Monty Hall (las cajas):
# Crear clase "Concurso":
# 3 opciones (cajas): una caja gana

# Jugador escoge 1 caja aleatorioa
# Presentador abre 1 caja (no escogida y no premiada)
# Aleatoriamente jugador cambia o no cambia de caja.

# Mostrar estadísticas de:
# Gana con cambio: % veces
# Gana sin cambio: % veces
# Pierde con cambio: % veces
# Pierde sin cambio: % veces

import random
caja1=False
caja2=False
Caja3=False



class concurso:
    puertas=[1,2,3]
    gana_con_ch=0
    sana_sin_ch=0

    
    def __init__(self):
        pass
    def concursar(self,iteraciones):
        for i in iteraciones:
            jugador= random.choice(self.puertas)
            puerta_premio=random.choice(self.puertas)
            if jugador==puerta_premio:
                fase_final=[]
                fase_final.append(jugador)
                self.puertas.remove(jugador)
                fase_final.append(random.choice(self.puertas))
            else:
                fase_final=[]
                fase_final.append(jugador)
                fase_final.append(puerta_premio)
            
    cambio= random.randint(0,1)
"""
            if cambio==0:
                if jugador==puerta_premio:
                    gana_sin_ch+=1
                else: pierde_sin_ch+=
                        
 """
            if cambio==0:
                fase_final.remove(jugador)
                if fase.final ==puerta
